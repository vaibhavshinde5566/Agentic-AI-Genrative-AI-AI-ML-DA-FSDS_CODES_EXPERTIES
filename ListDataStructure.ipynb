# %% [markdown]
# List
# #list is ordered , changable, and allow duplicates
# #list is write in square brakets
# #list store multiple elements
# #list methods
#  1>append()
#  2>copy()
#  3>insert()
#  4>extends()
#  5>remove()
#  6>pop()
#  7>reverse()
#  8>clear()

# %%
l = [12,32,24,34,65,34]
l.append(23)

# %% [markdown]
# l[0] = 21
# l

# %%
l.insert(2,35)
l
# Out:
# [12, 32, 35, 24, 34, 65, 34, 23]

# %% [markdown]
# l2 = l.copy()
# l2

# %%
l.count(12)
# Out:
# 1

# %%
l2 = [32,43,54]
l.extend(l2)
l
# Out:
# [12, 32, 35, 24, 34, 65, 34, 23, 32, 43, 54]

# %%
l.remove(35)
l
# Out:
# [12, 32, 24, 34, 65, 34, 23, 32, 43, 54]

# %%
l.reverse()
l
# Out:
# [54, 43, 32, 23, 34, 65, 34, 24, 32, 12]

# %%
l[:9:2]
# Out:
# [54, 32, 34, 34, 32]

# %%
l[:6]
# Out:
# [54, 43, 32, 23, 34, 65]

# %%
l
# Out:
# [54, 43, 32, 23, 34, 65, 34, 24, 32, 12]

# %%
l.sort()
l
# Out:
# [12, 23, 24, 32, 32, 34, 34, 43, 54, 65]

# %%
l3 = [12,'vaibhav',12.5,'shinde']         # Any datatype is allowed
l3
# Out:
# [12, 'vaibhav', 12.5, 'shinde']

# %%
l3[0]
# Out:
# 12

# %%
l4 = [32,43,42,'vaibhav',45.34,True]
l4
# Out:
# [32, 43, 42, 'vaibhav', 45.34, True]

# %%
l4.clear()         # clear function

# %%
l4
# Out:
# []

# %%
l
# Out:
# [12, 32, 24, 34, 65, 34, 23]

# %%
len(l)
# Out:
# 7

# %%
l.count(34)
# Out:
# 2

# %%
l.index(34)
# Out:
# 3

# %%
l.index(12)
# Out:
# 0

# %%
l.remove(32)

# %%
l
# Out:
# [12, 24, 34, 65, 34, 23]

# %%
l

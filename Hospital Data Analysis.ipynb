# %% [markdown]
# # Hospital Data Analysis

# %%
import pandas as pd
hos_data = pd.read_csv(r'D:\FSDS Naresh IT\25th, 26th- Advanced EDA project\EDA- HEALTHCARE DOMAIN\heart.csv')
hos_data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
hos_data.isnull().count()
# Out:
# age         303
# sex         303
# cp          303
# trestbps    303
# chol        303
# fbs         303
# restecg     303
# thalach     303
# exang       303
# oldpeak     303
# slope       303
# ca          303
# thal        303
# target      303
# dtype: int64

# %%
hos_data.shape
# Out:
# (303, 14)

# %%
hos_data.age
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
hos_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
hos_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
f, ax = plt.subplots(figsize=(8, 6))
vis = sns.countplot(data = hos_data,x = 'target')

# %%
hos_data.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8, 6))
vis1 = sns.countplot(data = hos_data,x = 'sex',hue = 'target')

# %%
vis2 = sns.catplot(data = hos_data,x = 'target',col = 'sex',kind = 'count',height = 5,aspect=1)

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(y="target", hue="sex", data=hos_data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
vis3 = sns.countplot(x="target", data=hos_data, palette="Set3")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1512\2511349932.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   vis3 = sns.countplot(x="target", data=hos_data, palette="Set3")

# %%
f, ax = plt.subplots(figsize=(8, 6))
vis4 = sns.countplot(data = hos_data,x="target", facecolor=(0, 0, 0, 0), linewidth=5, edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(data=hos_data , x="target", hue="fbs")
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(data = hos_data,x="target", hue="exang")
plt.show()

# %% [markdown]
# # Correlation

# %%
correlation = hos_data.corr()

# %%
correlation['target'].sort_values(ascending = False)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %%
hos_data['cp'].value_counts()
# Out:
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="cp", data=hos_data)
plt.show()

# %%
hos_data.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         104
#     1          39
# 1   1          41
#     0           9
# 2   1          69
#     0          18
# 3   1          16
#     0           7
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(data = hos_data,x="cp", hue="target")
plt.show()

# %%
ax = sns.catplot(data = hos_data,x="target", col="cp", kind="count", height=8, aspect=1)

# %%
hos_data['thalach'].nunique()
# Out:
# 91

# %%
f, ax = plt.subplots(figsize=(10,6))
x = hos_data['thalach']
ax = sns.distplot(x, bins=10)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1512\3685464387.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(x, bins=10)

# %%
f, ax = plt.subplots(figsize=(10,6))
x = hos_data['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.distplot(x, bins=10)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1512\2508027503.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(x, bins=10)

# %%
f, ax = plt.subplots(figsize=(10,6))
x = hos_data['thalach']
ax = sns.distplot(x, bins=10, vertical=True)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1512\1371283658.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(x, bins=10, vertical=True)

# %%
f, ax = plt.subplots(figsize=(10,6))
x = hos_data['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.kdeplot(x)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,6))
x = hos_data['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.kdeplot(x, shade=True, color='r')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1512\2905011135.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(x, shade=True, color='r')

# %%
f, ax = plt.subplots(figsize=(10,6))
x = hos_data['thalach']
ax = sns.distplot(x, kde=False, rug=True, bins=10)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1512\3801973382.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(x, kde=False, rug=True, bins=10)

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(data = hos_data,x="target", y="thalach")
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(data = hos_data,x="target", y="thalach", jitter = 0.01)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot( data=hos_data,x="target", y="thalach")
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
plt.figure(figsize=(16,12))
plt.title('Correlation Heatmap of Heart Disease Dataset')
a = sns.heatmap(correlation, square=True, annot=True, fmt='.2f', linecolor='white')
a.set_xticklabels(a.get_xticklabels(), rotation=90)
a.set_yticklabels(a.get_yticklabels(), rotation=30)           
plt.show()

# %%
# pair plot
num_var = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'target' ]
sns.pairplot(hos_data[num_var], kind='scatter', diag_kind='hist')
plt.show()

# %%
hos_data['age'].nunique()
# Out:
# 41

# %%
hos_data['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
f, ax = plt.subplots(figsize=(10,6))
x = hos_data['age']
ax = sns.distplot(x, bins=10)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1512\3408861319.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(x, bins=10)

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="target", y="age", data=hos_data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x="target", y="age", data=hos_data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.scatterplot(data = hos_data,x="age", y="trestbps")
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x="age", y="trestbps", data=hos_data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.scatterplot(x="age", y="chol", data=hos_data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x="age", y="chol", data=hos_data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.scatterplot(x="chol", y = "thalach", data=hos_data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x="chol", y="thalach", data=hos_data)
plt.show()

# %%
# check for missing values

hos_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#assert that there are no missing values in the dataframe

assert pd.notnull(hos_data).all().all()

# %%
#assert all values are greater than or equal to 0

assert (hos_data >= 0).all().all()

# %%
hos_data['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=hos_data["age"])
plt.show()

# %%
hos_data['trestbps'].describe()
# Out:
# count    303.000000
# mean     131.623762
# std       17.538143
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=hos_data["trestbps"])
plt.show()

# %%
hos_data['chol'].describe()
# Out:
# count    303.000000
# mean     246.264026
# std       51.830751
# min      126.000000
# 25%      211.000000
# 50%      240.000000
# 75%      274.500000
# max      564.000000
# Name: chol, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=hos_data["chol"])
plt.show()

# %%
hos_data['thalach'].describe()
# Out:
# count    303.000000
# mean     149.646865
# std       22.905161
# min       71.000000
# 25%      133.500000
# 50%      153.000000
# 75%      166.000000
# max      202.000000
# Name: thalach, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=hos_data["thalach"])
plt.show()

# %%
hos_data['oldpeak'].describe()
# Out:
# count    303.000000
# mean       1.039604
# std        1.161075
# min        0.000000
# 25%        0.000000
# 50%        0.800000
# 75%        1.600000
# max        6.200000
# Name: oldpeak, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=hos_data["oldpeak"])
plt.show()
